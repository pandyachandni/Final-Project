# %% [markdown]
# # Logistic Regression Model for 2016 data
#
# ### Logisitic Regression predicts binary outcomes. This model will analyze the available data, and when presented a new sample, mathematically determine its probability of belonging to a class. If the probability is above a certain cutoff point, the sample is assigned to that class. If the probability is less than the cutoff point, the sample is assigned to the other class.
#
# #### For our project, we will show how machine learning can help predict the safety of cities throughout the state of North Carolina.

# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
# Read the database
df = pd.read_csv(Path('NC_Crime_data_2016.csv'))
df.head()
# Out:
#         City  Population  Murder_ and_nonnegligent_manslaughter  Rape\n  \
# 0   Aberdeen        7549                                      0       3
# 1    Ahoskie        4883                                      2       3
# 2  Albemarle       16024                                      1       6
# 3     Angier        5097                                      0       2
# 4       Apex       47324                                      1       2
#
#    Robbery  Aggravated_assault  Burglary  Larceny_theft  Violent_crime_total  \
# 0       10                  12        52            226                   25
# 1        8                  30        81            201                   43
# 2       24                  76       201            538                  107
# 3        2                  10        62             59                   14
# 4       13                  24        83            501                   40
#
#    Motor_vehicle_theft  Property_crime_total  Arson  total_crime  Crime_index  \
# 0                   11                   289      1          314         4.15
# 1                    9                   291      0          334         6.84
# 2                   32                   771      4          878         5.48
# 3                    8                   129      3          143         2.81
# 4                   17                   601      1          641         1.35
#
#    is_safe
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1

# %%
# Identifying the data types of each column
dtypes_2016 = df.dtypes
print(dtypes_2016)
# Out:
# City                                      object
# Population                                 int64
# Murder_ and_nonnegligent_manslaughter      int64
# Rape\n                                     int64
# Robbery                                    int64
# Aggravated_assault                         int64
# Burglary                                   int64
# Larceny_theft                              int64
# Violent_crime_total                        int64
# Motor_vehicle_theft                        int64
# Property_crime_total                       int64
# Arson                                      int64
# total_crime                                int64
# Crime_index                              float64
# is_safe                                    int64
# dtype: object

# %%
# Cleaing the DataFrame
# Dropping Violent_crime_total & Property_Crime_total columns
# These columns are subtotals, we don't want to double count the data so we are dropping them
cleaned_df = df.drop(['Violent_crime_total','Property_crime_total', 'City'], axis=1)
cleaned_df.head()
# Out:
#    Population  Murder_ and_nonnegligent_manslaughter  Rape\n  Robbery  \
# 0        7549                                      0       3       10
# 1        4883                                      2       3        8
# 2       16024                                      1       6       24
# 3        5097                                      0       2        2
# 4       47324                                      1       2       13
#
#    Aggravated_assault  Burglary  Larceny_theft  Motor_vehicle_theft  Arson  \
# 0                  12        52            226                   11      1
# 1                  30        81            201                    9      0
# 2                  76       201            538                   32      4
# 3                  10        62             59                    8      3
# 4                  24        83            501                   17      1
#
#    total_crime  Crime_index  is_safe
# 0          314         4.15        1
# 1          334         6.84        0
# 2          878         5.48        1
# 3          143         2.81        1
# 4          641         1.35        1

# %%
# Splitting the Dataset into Train and Test Sets
# Creating our features
X = cleaned_df.drop(['is_safe'], axis=1)
X.head()
# Out:
#    Population  Murder_ and_nonnegligent_manslaughter  Rape\n  Robbery  \
# 0        7549                                      0       3       10
# 1        4883                                      2       3        8
# 2       16024                                      1       6       24
# 3        5097                                      0       2        2
# 4       47324                                      1       2       13
#
#    Aggravated_assault  Burglary  Larceny_theft  Motor_vehicle_theft  Arson  \
# 0                  12        52            226                   11      1
# 1                  30        81            201                    9      0
# 2                  76       201            538                   32      4
# 3                  10        62             59                    8      3
# 4                  24        83            501                   17      1
#
#    total_crime  Crime_index
# 0          314         4.15
# 1          334         6.84
# 2          878         5.48
# 3          143         2.81
# 4          641         1.35

# %%
# Creating our target
y = cleaned_df['is_safe']
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: is_safe, dtype: int64

# %%
X.describe()
# Out:
#           Population  Murder_ and_nonnegligent_manslaughter      Rape\n  \
# count     182.000000                             182.000000  182.000000
# mean    18838.131868                               1.467033    4.813187
# std     70201.579213                               5.874047   18.578138
# min       320.000000                               0.000000    0.000000
# 25%      2495.750000                               0.000000    0.000000
# 50%      4992.500000                               0.000000    1.000000
# 75%     14834.250000                               1.000000    3.000000
# max    896379.000000                              67.000000  219.000000
#
#            Robbery  Aggravated_assault     Burglary  Larceny_theft  \
# count   182.000000          182.000000   182.000000     182.000000
# mean     27.005495           64.087912   144.373626     514.670330
# std     160.527600          322.840164   531.463873    2119.694983
# min       0.000000            0.000000     0.000000       0.000000
# 25%       1.000000            3.000000    14.000000      52.250000
# 50%       3.000000           12.000000    44.000000     130.500000
# 75%      13.000000           34.000000   117.000000     373.000000
# max    2121.000000         4153.000000  6691.000000   27280.000000
#
#        Motor_vehicle_theft       Arson   total_crime  Crime_index
# count           182.000000  182.000000    182.000000   182.000000
# mean             36.483516    3.258242    792.967033     4.226538
# std             208.470747   16.986973   3355.770919     2.523421
# min               0.000000    0.000000      9.000000     0.380000
# 25%               2.000000    0.000000     90.000000     2.400000
# 50%               6.500000    0.000000    194.000000     3.890000
# 75%              19.000000    2.750000    566.750000     5.437500
# max            2761.000000  220.000000  43292.000000    15.640000

# %%
y.value_counts()
# Out:
# 1    146
# 0     36
# Name: is_safe, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
# Instantiate the Logistic Regression Model
classifier = LogisticRegression(solver='lbfgs', random_state=1)
classifier
# Out:
# LogisticRegression(random_state=1)

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
   intercept_scaling=1, max_iter=100, multi_class='auto', penalty='12',
   random_state=1, solver='lbfgs', warm_start=False)
# Out:
# LogisticRegression(penalty='12', random_state=1)

# %%
# Train the model
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
# Validate the Logistics Regression Model
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#      Prediction  Actual
# 85            1       1
# 150           1       1
# 101           1       1
# 31            1       1
# 159           1       1
# 161           1       1
# 163           1       1
# 27            1       1
# 69            0       0
# 11            1       1
# 144           1       1
# 12            1       1
# 35            1       1
# 121           1       1
# 60            1       1
# 45            0       0
# 148           1       1
# 77            1       1
# 107           1       1
# 10            1       1
# 30            1       1
# 47            1       1
# 50            1       1
# 131           1       1
# 63            0       0
# 93            0       0
# 2             1       1
# 1             0       0
# 20            1       1
# 5             0       0
# 61            0       0
# 56            1       1
# 81            1       1
# 73            1       1
# 29            1       1
# 91            1       1
# 140           1       1
# 96            0       0
# 97            1       1
# 175           1       1
# 80            1       1
# 70            1       1
# 138           1       1
# 4             1       1
# 181           1       1
# 67            0       0

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, predictions)
# Out:
# 1.0
