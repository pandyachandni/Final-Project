# %%
# Dependencies
import numpy as np
import pandas as pd

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("postgresql://postgres:Ec!1278379@localhost:5432/Final_Project")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# %load_ext sql

# %%
# %sql $engine.url

# %%
# %sql SELECT City from cities_2016
# Out:
#  * postgresql://postgres:***@localhost:5432/Final_Project
# 182 rows affected.
# [('Aberdeen',),
#  ('Ahoskie',),
#  ('Albemarle',),
#  ('Angier',),
#  ('Apex',),
#  ('Asheboro',),
#  ('Asheville',),
#  ('Atlantic Beach',),
#  ('Ayden',),
#  ('Bailey',),
#  ('Banner Elk',),
#  ('Beaufort',),
#  ('Beech Mountain',),
#  ('Belhaven',),
#  ('Belmont',),
#  ('Benson',),
#  ('Bessemer City',),
#  ('Biltmore Forest',),
#  ('Biscoe',),
#  ('Black Mountain',),
#  ('Blowing Rock',),
#  ('Boiling Spring Lakes',),
#  ('Boone',),
#  ('Brevard',),
#  ('Burgaw',),
#  ('Burlington',),
#  ('Butner',),
#  ('Cape Carteret',),
#  ('Carrboro',),
#  ('Carthage',),
#  ('Cary',),
#  ('Chapel Hill',),
#  ('Charlotte-Mecklenburg',),
#  ('Cherryville',),
#  ('Claremont',),
#  ('Clayton',),
#  ('Clinton',),
#  ('Clyde',),
#  ('Columbus',),
#  ('Concord',),
#  ('Conover',),
#  ('Creedmoor',),
#  ('Davidson',),
#  ('Dobson',),
#  ('Drexel',),
#  ('Duck',),
#  ('Eden',),
#  ('Edenton',),
#  ('Elizabeth City',),
#  ('Elkin',),
#  ('Elon',),
#  ('Emerald Isle',),
#  ('Erwin',),
#  ('Fairmont',),
#  ('Farmville',),
#  ('Fayetteville',),
#  ('Fletcher',),
#  ('Forest City',),
#  ('Fuquay-Varina',),
#  ('Garner',),
#  ('Gibsonville',),
#  ('Goldsboro',),
#  ('Graham',),
#  ('Granite Falls',),
#  ('Hamlet',),
#  ('Haw River',),
#  ('Henderson',),
#  ('Hendersonville',),
#  ('Hickory',),
#  ('Highlands',),
#  ('High Point',),
#  ('Holly Ridge',),
#  ('Holly Springs',),
#  ('Hope Mills',),
#  ('Hudson',),
#  ('Huntersville',),
#  ('Jefferson',),
#  ('Kannapolis',),
#  ('Kenansville',),
#  ('Kernersville',),
#  ('Kill Devil Hills',),
#  ('King',),
#  ('Kings Mountain',),
#  ('Kinston',),
#  ('Kitty Hawk',),
#  ('Knightdale',),
#  ('Lake Royale',),
#  ('Laurel Park',),
#  ('Laurinburg',),
#  ('Leland',),
#  ('Lenoir',),
#  ('Long View',),
#  ('Louisburg',),
#  ('Lumberton',),
#  ('Maiden',),
#  ('Manteo',),
#  ('Marion',),
#  ('Marshville',),
#  ('Matthews',),
#  ('Maxton',),
#  ('Mayodan',),
#  ('Maysville',),
#  ('Mebane',),
#  ('Mint Hill',),
#  ('Monroe',),
#  ('Mooresville',),
#  ('Morehead City',),
#  ('Mount Airy',),
#  ('Mount Holly',),
#  ('Mount Olive',),
#  ('Murphy',),
#  ('Nags Head',),
#  ('New Bern',),
#  ('Newland',),
#  ('Newport',),
#  ('Newton',),
#  ('North Wilkesboro',),
#  ('Oxford',),
#  ('Pilot Mountain',),
#  ('Pinebluff',),
#  ('Pinehurst',),
#  ('Pine Knoll Shores',),
#  ('Pine Level',),
#  ('Pineville',),
#  ('Pittsboro',),
#  ('Plymouth',),
#  ('Raeford',),
#  ('Randleman',),
#  ('Reidsville',),
#  ('Richlands',),
#  ('Roanoke Rapids',),
#  ('Robersonville',),
#  ('Rockingham',),
#  ('Rockwell',),
#  ('Rocky Mount',),
#  ('Rolesville',),
#  ('Rose Hill',),
#  ('Rowland',),
#  ('Rutherfordton',),
#  ('Salisbury',),
#  ('Selma',),
#  ('Shallotte',),
#  ('Shelby',),
#  ('Siler City',),
#  ('Snow Hill',),
#  ('Southern Pines',),
#  ('Spencer',),
#  ('Stallings',),
#  ('Stanley',),
#  ('Star',),
#  ('St. Pauls',),
#  ('Surf City',),
#  ('Swansboro',),
#  ('Sylva',),
#  ('Tabor City',),
#  ('Tarboro',),
#  ('Thomasville',),
#  ('Trent Woods',),
#  ('Troutman',),
#  ('Troy',),
#  ('Wadesboro',),
#  ('Wake Forest',),
#  ('Wallace',),
#  ('Warrenton',),
#  ('Warsaw',),
#  ('Washington',),
#  ('Waxhaw',),
#  ('Waynesville',),
#  ('Weaverville',),
#  ('Weldon',),
#  ('Wendell',),
#  ('West Jefferson',),
#  ('Whispering Pines',),
#  ('White Lake',),
#  ('Wilkesboro',),
#  ('Wilmington',),
#  ('Windsor',),
#  ('Winterville',),
#  ('Woodfin',),
#  ('Wrightsville Beach',),
#  ('Yadkinville',),
#  ('Youngsville',)]
